# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo-Ramos-Paz/Reposit-rio-PA/blob/main/13_03_Rodrigo_Ramos_Paz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Escrever um programa que soma dois números
# Entrada
a = int(input("Digite o primeiro número: "))
b = int(input("Digite o primeiro número: "))
# Processamento
soma = a + b
# Saída
print (f"O resultado da soma de {a} mais {b} é igual a {soma}")

# %%
# Escrever um programa que soma dois números
# Entrada
a = int(input("Digite o primeiro número: "))
b = int(input("Digite o primeiro número: "))
# Processamento
soma = a + b
subtracao = a - b
divisao = a / b
div_int = a // b
multiplicacao = a * b
resto = a % b
# Saída

print ("|--------------------------------------|")
print ("|--------CALCULADORA SIMPLES-----------|")
print ("|                                      |")
print ("|---------------SOMA-------------------|")
print (f"O resultado da soma de {a} mais {b} é igual a {soma}")
print ("|                                      |")
print ("|-------------SUBTRAÇÃO----------------|")
print (f"O resultado da subtração de {a} menos {b} é igual a {subtracao}")
print ("|                                      |")
print ("|--------------DIVISÃO-----------------|")
print (f"O resultado da divisão de {a} dividido por {b} é igual a {divisao}")
print ("")
print ("|----------DIVISÃO INTEIRA-------------|")
print (f"O resultado inteiro da divisão de {a} dividido por {b} é igual a {div_int}")
print ("|                                      |")
print ("|-----------MULTIPLICAÇÃO--------------|")
print (f"O resultado da multiplicação de {a} vezes {b} é igual a {multiplicacao}")
print ("|                                      |")
print ("|--------------RESTO-------------------|")
print (f"O resto de {a} dividido por {b} é igual a {resto}")
# Out:
# Digite o primeiro número: 12
# Digite o primeiro número: 6
# |--------------------------------------|
# |--------CALCULADORA SIMPLES-----------|
# |                                      |
# |---------------SOMA-------------------|
# O resultado da soma de 12 mais 6 é igual a 18
# |                                      |
# |-------------SUBTRAÇÃO----------------|
# O resultado da subtração de 12 menos 6 é igual a 6
# |                                      |
# |--------------DIVISÃO-----------------|
# O resultado da divisão de 12 dividido por 6 é igual a 2.0
#
# |----------DIVISÃO INTEIRA-------------|
# O resultado inteiro da divisão de 12 dividido por 6 é igual a 2
# |                                      |
# |-----------MULTIPLICAÇÃO--------------|
# O resultado da multiplicação de 12 vezes 6 é igual a 72
# |                                      |
# |--------------RESTO-------------------|
# O resto de 12 dividido por 6 é igual a 0
