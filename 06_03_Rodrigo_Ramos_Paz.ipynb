# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo-Ramos-Paz/Reposit-rio-PA/blob/main/06_03_Rodrigo_Ramos_Paz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CÁLCULO DO QUADRADO

# %%
#calcular o quadrado

#entrada
lado = 10
#processamento
resultado = lado * lado
#saída
print (f"o resultado da área do qudrado é: {resultado}")
# Out:
# o resultado da área do qudrado é: 100

# %% [markdown]
# #CÁLCULO DO RETÂNGULO

# %%
#Entrada
a = int(input("Digite o primeiro número: "))
b = int(input("Digite o primeiro número: "))

#Processamento
área = a * b

#Saída
print (f"Área total do retângulo é: {área} metros quadrados")
# Out:
# Digite o primeiro número: 12
# Digite o primeiro número: 15
# Área total do retângulo é: 180 metros quadrados

# %% [markdown]
# #DOBRO DE UM NÚMERO

# %%
#Entrada
numero = 123
#Processamento
resposta = numero * 2
#saída
print (f"O dobro de {numero} é igual a {resposta}")1
# Out:
# O dobro de 123 é igual a 246

# %% [markdown]
# #MÉDIA DE VALORES

# %%
#Entrada
num2 = 7
num3 = 5
num4 = 8
#Processamento
R = (num1 + num2 + num3 + num4) / 4
#Saída
print(f"A média dos valores é: {R}")
# Out:
# A média dos valores é: 5.75
