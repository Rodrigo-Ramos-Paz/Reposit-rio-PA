# %% [markdown]
# <a href="https://colab.research.google.com/github/Rodrigo-Ramos-Paz/Reposit-rio-PA/blob/main/20_03_Rodrigo_Ramos_Paz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CÁLCULO DO QUADRADO

# %%
#calcular o quadrado

#entrada
lado = 10
#processamento
resultado = lado * lado
#saída
print (f"o resultado da área do qudrado é: {resultado}")
# Out:
# o resultado da área do qudrado é: 100

# %% [markdown]
# #CÁLCULO DO RETÂNGULO

# %%
#Entrada
a = int(input("Digite o primeiro número: "))
b = int(input("Digite o primeiro número: "))

#Processamento
área = a * b

#Saída
print (f"Área total do retângulo é: {área} metros quadrados")
# Out:
# Digite o primeiro número: 12
# Digite o primeiro número: 15
# Área total do retângulo é: 180 metros quadrados

# %% [markdown]
# #DOBRO DE UM NÚMERO

# %%
#Entrada
numero = 123
#Processamento
resposta = numero * 2
#saída
print (f"O dobro de {numero} é igual a {resposta}")1
# Out:
# O dobro de 123 é igual a 246

# %% [markdown]
# #MÉDIA DE VALORES

# %%
#Entrada
num2 = 7
num3 = 5
num4 = 8
#Processamento
R = (num1 + num2 + num3 + num4) / 4
#Saída
print(f"A média dos valores é: {R}")
# Out:
# A média dos valores é: 5.75

# %% [markdown]
# #ADIÇÃO, SUBTRAÇÃO, DIVISÃO, DIVISÃO INTEIRA, MULTIPLICAÇÃO E RESTO

# %%
# Escrever um programa que soma dois números
# Entrada
a = int(input("Digite o primeiro número: "))
b = int(input("Digite o primeiro número: "))
# Processamento
soma = a + b
subtracao = a - b
divisao = a / b
div_int = a // b
multiplicacao = a * b
resto = a % b
# Saída


print ("SOMA")
print (f"O resultado da soma de {a} mais {b} é igual a {soma}")
print ("SUBTRAÇÃO")
print (f"O resultado da subtração de {a} menos {b} é igual a {subtracao}")
print ("DIVISÃO")
print (f"O resultado da divisão de {a} dividido por {b} é igual a {divisao}")
print ("DIVISÃO INTEIRA")
print (f"O resultado inteiro da divisão de {a} dividido por {b} é igual a {div_int}")
print ("MULTIPLICAÇÃO")
print (f"O resultado da multiplicação de {a} vezes {b} é igual a {multiplicacao}")
print ("RESTO")
print (f"O resto de {a} dividido por {b} é igual a {resto}")
# Out:
# Digite o primeiro número: 03
# Digite o primeiro número: 32
# SOMA
# O resultado da soma de 3 mais 32 é igual a 35
# SUBTRAÇÃO
# O resultado da subtração de 3 menos 32 é igual a -29
# DIVISÃO
# O resultado da divisão de 3 dividido por 32 é igual a 0.09375
# DIVISÃO INTEIRA
# O resultado inteiro da divisão de 3 dividido por 32 é igual a 0
# MULTIPLICAÇÃO
# O resultado da multiplicação de 3 vezes 32 é igual a 96
# RESTO
# O resto de 3 dividido por 32 é igual a 3

# %% [markdown]
# ATIVIDADE
#
# Escreva um programa que receba a temperatura em graus celsius e converte para fahrenheit
#
# Entrada
#
# Graus celsius
#
# Processamento
#
# F° = C° x (9/5) + 32
#
# Saída
#
# Mostrar graus em fahrenheit

# %%
# Entrada

Celsius = int (input(f"digite a temperatura em graus celsius: "))

# Processamento

Fahrenheit = Celsius * (9/5) + 32

# Saída

print (f"a temperatura em fahrenheit é: {Fahrenheit} F°")
# Out:
# digite a temperatura em graus celsius: 12
# a temperatura em fahrenheit é: 53.6 F°
